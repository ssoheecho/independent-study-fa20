# %%
from PIL import Image
import glob
import os

# %%
directory = '/Users/soheecho/Code/is/z_data/gan_images_eur/*.jpg'
image_paths = [f for f in glob.glob(directory)]
image_paths
# Out:
# ['/Users/soheecho/Code/is/z_data/gan_images_eur/img_329.jpg',
#  '/Users/soheecho/Code/is/z_data/gan_images_eur/img_3284.jpg',
#  '/Users/soheecho/Code/is/z_data/gan_images_eur/img_1493.jpg',
#  '/Users/soheecho/Code/is/z_data/gan_images_eur/img_1487.jpg',
#  '/Users/soheecho/Code/is/z_data/gan_images_eur/img_4266.jpg',
#  '/Users/soheecho/Code/is/z_data/gan_images_eur/img_1478.jpg',
#  '/Users/soheecho/Code/is/z_data/gan_images_eur/img_1450.jpg',
#  '/Users/soheecho/Code/is/z_data/gan_images_eur/img_3247.jpg',
#  '/Users/soheecho/Code/is/z_data/gan_images_eur/img_1444.jpg',
#  '/Users/soheecho/Code/is/z_data/gan_images_eur/img_659.jpg',
#  '/Users/soheecho/Code/is/z_data/gan_images_eur/img_665.jpg',
#  '/Users/soheecho/Code/is/z_data/gan_images_eur/img_4716.jpg',
#  '/Users/soheecho/Code/is/z_data/gan_images_eur/img_3737.jpg',
#  '/Users/soheecho/Code/is/z_data/gan_images_eur/img_1097.jpg',
#  '/Users/soheecho/Code/is/z_data/gan_images_eur/img_3858.jpg',
# ...

# %%
print(len(image_paths))
# Out:
# 489

# %%
for index, path in enumerate(image_paths):
    image = Image.open(path)
    print(image.size)
    new_image = image.resize((400, 400))
    num = 195 + index
    new_image.save('/Users/soheecho/Code/is/data/gan_images_resized/img_{}.jpg'.format(num))
# Out:
# (1285, 1933)
# (1208, 1920)
# (1064, 1564)
# (381, 624)
# (892, 1824)
# (599, 455)
# (1808, 1204)
# (1624, 1948)
# (441, 625)
# (2610, 3840)
# (458, 625)
# (401, 624)
# (1184, 1832)
# (1536, 2048)
# (2663, 4000)
# (2875, 4000)
# (4000, 3000)
# (496, 624)
# (3200, 4000)
# (2976, 3722)
# (448, 625)
# (1296, 1832)
# (2803, 3738)
# (466, 624)
# (2988, 4000)
# (1016, 1916)
# (1056, 2000)
# (499, 624)
# (1372, 1912)
# (465, 624)
# (3200, 4000)
# (449, 625)
# (958, 2048)
# (403, 624)
# (2695, 4000)
# (2933, 4000)
# (425, 625)
# (1168, 1796)
# (1568, 1952)
# (1776, 1168)
# (924, 1824)
# (3146, 4000)
# (1152, 1888)
# (1152, 1864)
# (1080, 1920)
# (395, 624)
# (600, 397)
# (287, 624)
# (864, 1836)
# (2937, 4000)
# (1176, 1856)
# (649, 700)
# (1956, 1436)
# (2854, 4000)
# (2571, 4000)
# (3200, 4000)
# (1311, 2048)
# (600, 450)
# (4000, 2984)
# (3180, 4000)
# (1173, 1997)
# (1076, 1856)
# (445, 700)
# (364, 624)
# (397, 624)
# (1136, 1948)
# (362, 625)
# (2978, 4000)
# (4000, 3000)
# (400, 625)
# ...

# %%
image = Image.open('data/gan_images/img_577.jpg')

# %%
print(image.size)
# Out:
# (2000, 2000)

# %%
image_1 = Image.open('data/gan_images/img_682.jpg')

# %%
print(image_1.size)
# Out:
# (1669, 2000)

# %%
new_image = image.resize((400, 400))

# %%
print(new_image.size)
# Out:
# (400, 400)

# %%
new_image.show()
